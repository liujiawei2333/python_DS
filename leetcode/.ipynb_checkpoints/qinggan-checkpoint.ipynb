# %%
import pandas as pd
from pandas import read_csv

dataset = read_csv('boardData.csv', encoding='gbk',header=0, index_col=0)#读入数据
values = dataset.values
print(values[:,10])
# Out:
# [['别眨眼，这部手机真的很Ace' '5' '产品' '1.9053E+18' 'Ace系列' '558' '1589' '26'
#   '4518547' '4' '别眨眼，这部手机真的很Ace！4月13日，期待与你相见！' '2020/4/8 17:48'
#   '2020/4/8 18:13' '2020/4/8 17:49' '2020/4/8 22:35' '1.68169E+18'
#   '103461' 'Lv.16 声名显赫Ⅳ' 'Lv.6 正式出道Ⅱ' '懒鱼儿' '锄禾灬丿' "['7']"
#   "['点赞数达到【数值】']"]
#  ['ColorOS 7 For Reno 正式版开放升级！' '5' '产品' '20' 'Reno系列' '952' '2930' '54'
#   '4580835' '4'
#   '各位Reno用户好，ColorOS7ForReno正式版开放升级啦！机型：Reno\\Reno灵感版正式版版本号：C.08ColorOS7更多机型适配进度请查看：ColorOS7xAndroid10适配进度集合帖升级方式：'
#   '2020/4/7 18:26' '2020/4/8 9:18' '2020/4/8 9:18' '2020/4/8 22:28'
#   '103464' '103459' 'Lv.9 小有名气Ⅰ' 'Lv.4 见习萌新Ⅳ' '木头的' '幽草晚晴wzx' "['7']"
#   "['点赞数达到【数值】']"]
#  ['ColorOS 7 For Reno 10倍变焦版正式版开放升级！' '5' '产品' '20' 'Reno系列' '1021'
#   '3118' '68' '4580835' '4'
#   '各位Reno10倍变焦版用户好，ColorOS7ForReno10倍变焦版正式版开放升级啦！机型：Reno10倍变焦版、Reno巴萨定制版正式版版本号：C.20ColorOS7更多机型适配进度请查看：ColorOS7xA'
#   '2020/4/7 18:39' '2020/4/8 9:20' '2020/4/8 9:20' '2020/4/8 22:37'
# ...
